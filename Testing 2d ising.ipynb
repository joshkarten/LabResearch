# %%
from ClassesSim import MCCTClassical
import numpy as np 
import matplotlib.pyplot as plt
from fractions import Fraction
def binder(param):
    return 1-np.average(param**4, axis=0)/(3*np.average(param**2,axis=0)**2)
def binderr(param):
    first = -1/(3*np.average(param**2,axis=0)**2) * np.std((param)**4,axis=0,ddof=1)/np.sqrt(len(param[:,0,0,0]))
    second = np.average(param**4, axis=0)/(np.average(param**2,axis=0)**3)*np.std(param*2,axis=0,ddof=1)/np.sqrt(len(param[:,0,0,0]))
    return np.sqrt(first**2+second**2)

# %%
Iising = MCCTClassical(10,10,10,int(1e4),np.geomspace(0.01,10,10),[0],1,-1,0,1,1/2,False)

# %%
110*10*100/60/60
# Out:
# 30.555555555555554

# %%
Iising.Simulation()
fig,ax=plt.subplots()
rec=ax.imshow(Iising.recordMag[-1,:,:,-1],aspect='auto')
fig.colorbar(rec, ax=ax, location ='right', shrink = 1)

# %%
110/1e6
# Out:
# 0.00011

# %%
np.reshape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 np.reshape()
#
# TypeError: reshape() missing 2 required positional arguments: 'a' and 'newshape'

# %%
b = binder(np.reshape(Iising.recordMag[:,200:,:,:],(20*200,-1,1)))
fig,ax=plt.subplots()
ax.plot(Iising.betarange,b[:,-1])

# %%
fig,ax=plt.subplots()
rec=ax.imshow(Iising.recordMag[0,:,:,-1],aspect='auto')
fig.colorbar(rec, ax=ax, location ='right', shrink = 1)
